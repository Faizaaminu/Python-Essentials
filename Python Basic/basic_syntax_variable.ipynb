# %% [markdown]
# # Basic Syntax and Variables

# %% [markdown]
# ## python version
# - checking python version in commandline<br><br>
# - checking python version in notebook<br><br>

# %%
#checking python version in notebook
# !python --version
# Out:
# Python 3.13.2

# %%
# Check Python Version Using Python Code
import sys # import system module

# Print the Python version using sys module
print(sys.version)
# Out:
# 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## variables in Python

# %% [markdown]
# ##### variables are names that refers to a specific value, which can be any of data type.
# 1. Varible names contain letters,numbers,underscores (A-Z,0-9,_)<br><br>
# 2. Varible names are case-sensitive.<br><br>
# 3. varible names should be short and descriptive.<br><br>
# 4. Variable names cannot be the same as a python keyword. however avoid using python keywords and  function names as variable names(e.g "if", "else","while")

# %%
# variable names must start with a letter or underscore_
# valid names:
name="Alice"
_age=25
totalamount=100

# Invalid names
# @name="Bob" Return error!cannnot start with special character
# name="Bob" error !cannot start with a number

# %%
message = "Hello pyhton World"

# %%
message
# Out:
# 'Hello pyhton World'

# %%
message = "Hello pyhton World "
print(message) #print is a python keyword that print the value of the varible to the console
# Out:
# Hello pyhton World

# %%
#createssavin a variable Savings
savings=100
print(savings)
# Out:
# 100

# %%
x=str(2)   #'2'
y=int(2)   # 2
z=float(2)    #2.0
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Multi Words Varibles Names

# %%
#Pascal Case: Each word starts with a capital letter
MyVariableName="John"

# %%
#Camel Case:Each words start with a capital letter except the first
myVariableName="John"

# %%
#Snake Case:Each word is seperated by an underscore character
my_variable_name="John"

# %%
#Multiple variable in one line
x,y,z="Orange","Banana","Mango"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Mango

# %% [markdown]
# ## TraceBack
#
# - When an error occurs in your program, the Python interpreter provides a traceback  when a program cannot run successfully.  <br></br>
# - A traceback is a record of where the interpreter ran into trouble when trying to execute your code.  <br></br>
# - Here’s an example of the traceback that Python provides after you’ve accidentally misspelled a variable’s name: <br></br>

# %%
print(hello, world)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(hello, world)
#
# NameError: name 'hello' is not defined

# %% [markdown]
# >python is case-sensitive

# %%
name="Bob"
print(Name) # case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 name="Bob"
# ----> 2 print(Name) # case sensitive
#
# NameError: name 'Name' is not defined

# %% [markdown]
# > Interpreter tell us what kind of error occurs name error (A name error usually means we either forgot to set a variable’s value before using it, or we made a spelling mistake when entering the variable’s name).

# %% [markdown]
# ## Syntax Error
#   >A syntax error occurs when you write code that isn't allowed in the python language

# %%
print("Hello world)
# Out:
#   Cell In[2], line 1
#     print("Hello world)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ## Indentation

# %% [markdown]
# >Indentation in python refers to the spaces or tabs that are used at begining of a line of code  to define the structure or hierarchy of the program

# %% [markdown]
# Indentaion Rules in Python
# 1. Use 4 spaces per indentation level
# 2. used of tab
# 3. Every block of code (under if, for, while, class, def) must ne indented consistently
# 4. Nested blocks require multiple level of indentaton
#    - `NB` Python used indentation to indicate a block of code

# %%
if 5>2:
    print("Five is greater than 2 !")
# Out:
# Five is greater than 2 !

# %%
age=18
if age >=18:
    print("you are an Adult")
    print("you can vote")
# Out:
# you are an Adult
# you can vote

# %%
## Incorrect indentation
age=18
if age >=18:                           
print("you are an Adult")
print("you can vote")
# Out:
#   Cell In[4], line 4
#     print("you are an Adult")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %% [markdown]
# ### Different types of variables that can be used to store different kinds of data
# - integer:store whole number such as 5, 10, 100.<br></br>
# - Float: stores decimal number such 3.14, 0.5. <br></br>
# - String: storfe text or characters such as "Hello World".  <br></br>
# - Boolean: store a avalue that is either True or False. <br></br>

# %%
# integer
x=10
y=20

#float
radius=5.0

#string
greeting="Hello World"

#Boolean
is_sunny=True
is_raining=False

# %%
# assigning two variable x and y
x=2 # which assign as a number
y="2" # y assign as a string
print(x)
print(y)

# %% [markdown]
# ## Comment
# >Comment are line of text that don't affect the way a program runs.
# comment start with a #
# - Block comment start on a new line
# - inline comment appear on the same line as the code they reference</bra>

# %%
# This is a block comment.
greeting="Hello, World"
print(greeting) # This is an inline comment

# %% [markdown]
# >you can also use comment to **comment out code** while you are testing a program.

# %%
# This is my first program
# it prints the phrase "Hello, World"
# the comment are longer than the code
greeting="Hello, World"
# print(greeting)

# %% [markdown]
# >Comment start with **#** (single-line) or triple quote **("""  """)** for multi-line comment.

# %%
# This is a single comment


""" this is a multi-line comment
explaining the code below
"""

# %% [markdown]
# ## Statements

# %%
print("Hello world!")
print("Have a nice day.")
print("Learning Python os fun!")
# Out:
# Hello world!
# Have a nice day.
# Learning Python os fun!

# %% [markdown]
# Print without a new line

# %%
print("Hello world!", end=" ")
print("Learning Python os fun!")
# Out:
# Hello world! Learning Python os fun!

# %%
print("I am", 34, "Years old.")
# Out:
# I am 34 Years old.

# %% [markdown]
# ## Strings
#
# - A string is a series of characters. <br></br>
#
# - Anything inside quotes is considered a string in Python, and you can use single or double quotes around your strings like <br></br>

# %%
"This is a string"   # using Double quote
'This is also a string'  # using single quote

# %%
print(" This is a string")
print('This is a string')

# %% [markdown]
# > flexibility of using both single and double quote allows us to use quotes and apostrophes within your strings:

# %%
'I told my friend, "Python is my favorite language!" '
# Out:
# 'I told my friend, "Python is my favorite language!" '

# %%
"The language 'Python' is named after Monty Python, not the snake."

# %%
type("Hello, World")  #output will indicate that the is an instance of the str data type

# %% [markdown]
#  ## String have three important property
#  1. Strings contain individual letters or symbols called characters.<br></br>
#  2. Strings have a length,defined as the number of character the string contains.<br></br>
#  3. characters in astring appear in sequence, which means each character has a numbered position in the string.

# %%
name="faiza amimnu"
name.title()
# Out:
# 'Faiza Amimnu'

# %%
name.upper()
# Out:
# 'FAIZA AMIMNU'

# %%
#check for type
type("hello world")
# Out:
# str

# %%
#length of a string
message="hello world"
print(len(message))
# Out:
# 11

# %%
#Multiline string using triple quote as delimeter
paragraph="""this planet has-or rather had-a problem, which was this: most of the people living on it were unhappy for pretty much of the time. many solution were suggested for this problem, butcmost of this were largely concered with the the movement of small green pieces of paper, which is odd because on the whole it wasn't the small green piece of paper that were unhappy."""
print(paragraph)
# Out:
# this planet has-or rather had-a problem, which was this: most of the people living on it were unhappy for pretty much of the time. many solution were suggested for this problem, butcmost of this were largely concered with the the movement of small green pieces of paper, which is odd because on the whole it wasn't the small green piece of paper that were unhappy.

# %% [markdown]
# ### Concatenation, Indexing and Slicing

# %% [markdown]
# 1. Concatenatio:which join two string together<br></br>
# 2. Indexing:which get a single character from a string<br></br>
# 3. Slicing:which get several characters from a string at once.<br></br>

# %% [markdown]
# ### String Concatenate

# %%
#concatenate
#combining two string using the + operator
string1="bed"
string2="room"
magic_string=string1 + string2
magic_string
# Out:
# 'bedroom'

# %%
first_name="mary"
last_name="john"
full_name=first_name +" "+last_name
full_name
# Out:
# 'mary john'

# %% [markdown]
# ### String Indexing

# %%
flavor="fig pie"
flavor[1] #this return second character at position 1 in fig pie
# Out:
# 'i'

# %%
flavor[:3]
# Out:
# 'fig'

# %%
flavor[3:]
# Out:
# ' pie'

# %%
flavor[-1] # this return the last character
# Out:
# 'e'

# %% [markdown]
# >if you want to alter a string, then you must create an entirely new string. To change the string "goal" to"foal" ,you ca use astring slice to concatenate the letter"f" with everthing but the first letter of the word "goal"</br>

# %%
word="goal"
word="f"+word[1:]
word
# Out:
# 'foal'

# %% [markdown]
# ### String Slicing

# %%
first_three_letter=flavor[0]+flavor[1]+flavor[2]
first_three_letter
# Out:
# 'fig'

# %% [markdown]
# ## String Method

# %% [markdown]
# ### converting string to upper case or lower case

# %%
"jean piget".upper()
# Out:
# 'JEAN PIGET'

# %% [markdown]
# ### Removing whitespace from a string
# - .rstip():remove whitespace from the rightside
# - lstrip():remove whitespace from the leftside
# - .strip()

# %%
name="Jean Piget      "
name
# Out:
# 'Jean Piget      '

# %%
name.rstrip()
# Out:
# 'Jean Piget'

# %%
name="       Jean Piget     "
name
# Out:
# '       Jean Piget     '

# %%
name.strip()
# Out:
# 'Jean Piget'

# %% [markdown]
# >Determine if a string start with or ends with a particular string</br>

# %%
starship="Enterprise"
starship.startswith("En")
# Out:
# True

# %%
starship.endswith("tre")
# Out:
# False

# %% [markdown]
# ### using string with Arithmetics Operators

# %%
num="2"
num+num
# Out:
# '22'

# %% [markdown]
# >the +  operator concatenate two strings together, which is why the result of"2" + "2" is"22" and not "4"

# %%
num="12"
num*3 # this will concatenate three instance of the string"12" and return the string "12122"
# Out:
# '121212'

# %% [markdown]
# ### Converting Strings to Numbers

# %%
num=input("Enter a number to be doubled:")
doubled_num=num*2
print(doubled_num)
# Out:
# 44

# %% [markdown]
# ### Converting Numbers to Strings

# %%
num_pancakes=10
"I am going to eat" + str(num_pancakes ) + "pancakes."
# Out:
# 'I am going to eat10pancakes.'

# %% [markdown]
# >you can also call a String on a number literal</br>

# %%
"I am going to eat " + str(10 ) + " pancakes."
# Out:
# 'I am going to eat 10 pancakes.'

# %% [markdown]
# >str( can even handle arithmetics expression)

# %%
total_pancakes=10
pancakes_eaten=5
"only " + str(total_pancakes - pancakes_eaten) +" pancakes left."
# Out:
# 'only 5 pancakes left.'

# %%
total_pancakes=10
pancakes_eaten=5
"only " + str(10 -5) +" pancakes left."
# Out:
# 'only 5 pancakes left.'

# %%
## create the variable monthly_saving and num_months
monthly_savings=10
num_months=4

## Multiply monthly_saving and num_months
new_savings=monthly_savings *num_months

#print new_savings
print(new_savings)
# Out:
# 40

# %% [markdown]
# ### Find a String in a Str
# >using.find() method. this method allow you to find the location of a one string in another string- referred to as Substrings</br>

# %%
phrase="the surprise ie=s in here"
phrase.find("surprise")
# Out:
# 4

# %% [markdown]
# __F-Strings__

# %% [markdown]
# To specify a  string in an f-string , simply put an `f` in front of the string, and add a curly brackets`{}` as a placeholders for variables and other operation,
# - Placeholder: can contain variable,operation, functions, and modifiers to format the value.
# - Modifier : included by adding a colon`:` followed by legal formatting type `.2f` which means fixed point number with 2 decimals.

# %%
price=59
txt=f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %% [markdown]
# Escape Characters
# -----------------------

# %% [markdown]
# An escape caharacter is backlash` \` folllowed by the character you want to insert

# %%
var="We are the so called \"Vikings\" from the north."
var
# Out:
# 'We are the so called "Vikings" from the north.'

# %%
greeting="Hello\tWorld!"
greeting
# Out:
# 'Hello\tWorld!'

# %%
greeting="Hello\nWorld!"
greeting
# Out:
# 'Hello\nWorld!'

# %% [markdown]
# | Code|Discription                                               |
# |-------------|---------------------------------------------------------|
# |`\()`    |Single Quote. </br>  |
# |`\\()`        | Backlash. </br> |
# |`\n()`  |new line . </br> |
# |`\r()` | Carriage Return. </br> |
# |`\t()`  | Tab.</br> |
# |`\b()` | Backspace. </br |
# |`\f()` | Form Feed . </br>|
# |`\ooo()`    |Octal value. </br>|
# |`\xhh()`     |Hex value. </br>|

# %% [markdown]
# __String Methods__

# %% [markdown]
# | Code|Discription                                               |
# |-------------|---------------------------------------------------------|
# |`capitalize()`    |Convert the first character to upper case. </br>  |
# |`casefold()`        | Converts string into lower case. </br> |
# |`center()`  |Return a centered string</br> |
# |`count()` | Return the number of times a specified value occurs in a string. </br> |
# |`encode()`  | Return an encoded version of the string.</br> |
# |`endwith()` | Return true if the string ends with specified value. </br |
# |`expandtabs()` |Sets the tab size of the string . </br>|
# |`find()`    |Searches the string for a specified value and returns the position of where it was found. </br>|
# |`format()`     |Formats specified values in a string. </br>|
# |`format_map()`     |Formats specified values in a string. </br>|
# |`index()`     |Searches string for a specified value and returns the position of where it was found. </br>|
# |`isalnum()`     |Return True if all characters in the string are alphanumeric. </br>|
# |`isalpha()`     |Return True if all characters in the string are alphabete. </br>|
# |`isascii()`     |Return True if all characters in the string are ascii character. </br>|
# |`isdecimal()`     |Return True if all characters in the string are decimals. </br>|
# |`isdigit()`     |Return True if all characters in the string are digits. </br>|
# |`isidentifier()`     |Return True if  the string is an identifier. </br>|
# |`islower()`     |Return True if all characters in the string are lower case. </br>|
# |`isnumeric()`     |Return True if all characters in the string are numeric. </br>|
# |`isprintable()`     |Return True if all characters in the string are dprintable. </br>|
# |`isspace()`     |Return True if all characters in the string are whitespace. </br>|
# |`isupper()`     ||Return True if all characters in the string are upper case. </br>|
# |`join()`     |join the elements of an iterable to end of the string </br>|
# |`ljust()`     |Return a left justified version of the string. </br>|
# |`lower()`     |Converts a string into lower case. </br>|
# |`istrip()`     |Return Ta left trim version of the string. </br>|
# |`maketrans()`  |Return a translation table to be used in translation. </br>|
# |`partition()`   |Return a tuple where the string is parted into theree parts </br>|
# |`replace()`     |Return a string where a specified value is replaced with a specified value. </br>|
# |`rfind()`     |Searches the string for a specified value and returns the last position of where it was found </br>|
# |`rindex()`     |Searches the string for a specified value and returns the last position of where it was found . </br>|
# |`rpartition()`     |Return a tuple where the stringis parted into three parts. </br>|
# |`rjust()`     |Return a right justified version of the string. </br>|
# |`rspilt()`     |Spilt the string at the specified seperator, an return a list. </br>|
# |`rstrip)`     |Return a right trim version of the string. </br>|
# |`spilt()`     |Splits the string at the specified seperator, and return a list. </br>|
# |`splitlines()`|Splits the dtring at line break and return a list. </br>|
# |`startwith()` |Return true if the string start with the soecified value. </br>|
# |`strip()`     |Return a right justified version of the string. </br>|
# |`swapcase()`   |Swaps cases, lower caese become upper case and vice versa. </br>|
# |`title()`     |Converts the first character of each word to upper case. </br>|
# |`translate()`     |Return a translated string. </br>|
# |`upper()`     |Converts a string into upper case. </br>|
# |`zfill()`     |Fills the string with a specified number of 0 values at the begining. </br>|
